# %%
from os import listdir
from os.path import isfile, join
from utils.tools import *

# %%
path=r"C:\Users\cjang\Desktop\Kyler_Speed_Circuit\data\\"
data = ['DE_40_2_60.mpt']
ex_mpt = mpt_data(path,data)

# %%
ex_mpt.mpt_plot()
# Out:
# No handles with labels found to put in legend.

# %%
ex_mpt.set_new_gph_dims(20,20)
ex_mpt.mpt_plot(x_window= [50,300], y_window= [0,300])
# Out:
# No handles with labels found to put in legend.

# %%
ex_mpt.window_masker(x_window = [0, 300], y_window = [0,300])
# Out:
# [1000018.6, 398.0892]

# %%
masked_mpt = mpt_data(path,data, mask = ex_mpt.window_masker(x_window = [0, 300], y_window = [0,300]))

# %%
masked_mpt.set_new_gph_dims(20,20)

# %%
masked_mpt.mpt_plot()
# Out:
# No handles with labels found to put in legend.

# %%
masked_mpt.guesser(path)
# Out:
#  ERROR:  240801.38843840506
# MPT FILE :  DE_40_2_60.mpt  ERROR:  240794.1251758777
# MPT FILE :  DE_40_2_60.mpt  ERROR:  240801.379862255
# MPT FILE :  DE_40_2_60.mpt  ERROR:  240801.38153654325
# MPT FILE :  DE_40_2_60.mpt  ERROR:  532379.1978823859
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.74891390328
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.78596038981
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.74428136948
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.74891222127
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.74900085332
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.74976832469
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117483.61729357344
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117472.11161750008
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.73157645515
# MPT FILE :  DE_40_2_60.mpt  ERROR:  117482.73576275012
# MPT FILE :  DE_40_2_60.mpt  ERROR:  137557.50795371353
# MPT FILE :  DE_40_2_60.mpt  ERROR:  59420.2251499284
# MPT FILE :  DE_40_2_60.mpt  ERROR:  59420.22601661172
# ...
