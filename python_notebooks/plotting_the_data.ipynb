# %%
#Locate the data, prepare for import of the MPT file
#Import necessary packaging
from utils.tools import *

#EXAMPLE
path=r"C:\Users\cjang\Desktop\\"
data = ['DE_40_1_30.mpt']
ex_mpt = mpt_data(path,data)

# %%
ex_mpt.mpt_plot()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Graph Dimensions
# We can change the dimensions of the graph by calling on set_new_gph_dims(height, width) and customizing the size of the graph to our liking.

# %%
#Say we want to make our graph 8 inches by 8 inches
ex_mpt.set_new_gph_dims(8,8)
ex_mpt.mpt_plot()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Graph Window
# We can not only change the size of the graph, but we can also customize the window of the graph we're looking at by calling on mpt plot, but this time, call out x_window = [x_min, x_max] and y_window = [y_min, y_max] and plant that into the plotting function.

# %%
ex_mpt.mpt_plot(x_window = [0,5000], y_window = [0,5000])
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Fitting and Residuals
# There are also two attributes in mpt_plot() that can be called after the fitting process has been fitted. The first is the fitting = 'on' attribute, which allows the user to view the Nyvquist Impedance graph with the fitting equation layered on top of it. It is off if it is not called. There is also the residual attribute, denoted by rr = 'on' which can also be switched on and off by typing the state into the mpt_plot() function. The residual attribute plots the original graph, and also plots another graph with the residuals of the fitted equation and the actual graph.

# %%
#Turn on fitting option
#ONLY WORKS AFTER FITTING THE GRAPH
ex_mpt.mpt_plot(fitting = 'on', rr = 'on')
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6d25ace6da2a> in <module>
#       1 #Turn on fitting option
#       2 #ONLY WORKS AFTER FITTING THE GRAPH
# ----> 3 ex_mpt.mpt_plot(fitting = 'on', rr = 'on')
#
# c:\Users\cjang\Desktop\impedance_data\python_notebooks\utils\tools.py in mpt_plot(self, fitting, rr, legend, x_window, y_window)
#     170                 self.rr_imag = []
#     171                 for i in range(len(self.df)):
# --> 172                     self.rr_real.append(residual_real(re=self.df[i].re.values, fit_re=self.circuit_fit[i].real, fit_im=-self.circuit_fit[i].imag))
#     173                     self.rr_imag.append(residual_imag(im=self.df[i].im.values, fit_re=self.circuit_fit[i].real, fit_im=-self.circuit_fit[i].imag))
#     174                     if legend == 'on':
#
# ...

# %%
# Hasn't been fitted, so the above can't work

# %%
#FITTING!!
Rs_guess = 40

R_guess = 2959
n_guess = 0.8
fs_guess = 23023

R2_guess = 258738
n2_guess = 0.8
fs2_guess = 0.2

ex_mpt.guesser(Rs_guess,R_guess,n_guess,fs_guess,R2_guess,n2_guess,fs2_guess)
# Out:
#   =  0.399
#     C(fs, fs2) = -0.379
#     C(fs, R2)  =  0.365
#     C(Rs, n2)  = -0.353
#     C(n, fs)   =  0.302
#     C(Rs, fs2) = -0.291
#     C(Rs, R2)  =  0.281
# None
# ITERATION NO:  985
# total error:  4.661156460805671e-10
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 15
#     # data points      = 240
#     # variables        = 7
#     chi-square         = 309619.885
#     reduced chi-square = 1328.84071
#     Akaike info crit   = 1732.99081
#     Bayesian info crit = 1757.35529
# [[Variables]]
#     Rs:   0.40000000 +/- 39.5481986 (9887.05%) (init = 0.4)
#     R:    3966.77131 +/- 99.5935031 (2.51%) (init = 3966.771)
#     n:    0.65000000 +/- 0.02376554 (3.66%) (init = 0.65)
#     fs:   11354.5503 +/- 729.407646 (6.42%) (init = 11354.55)
#     R2:   2586062.43 +/- 399497.780 (15.45%) (init = 2586062)
#     n2:   0.81097575 +/- 0.00354298 (0.44%) (init = 0.8109757)
#     fs2:  0.02156687 +/- 0.00448916 (20.82%) (init = 0.02156687)
# ...

# %%
#The top graph shows a fitted graph, and the bottom graph shows the residuals
ex_mpt.mpt_plot(fitting = 'on', rr = 'on')
# Out:
# No handles with labels found to put in legend.
# c:\Users\cjang\Desktop\impedance_data\python_notebooks\utils\tools.py:172: FutureWarning: `real` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.real(ser.to_numpy())` or `ser.to_numpy().real`.
#   self.rr_real.append(residual_real(re=self.df[i].re.values, fit_re=self.circuit_fit[i].real, fit_im=-self.circuit_fit[i].imag))
# c:\Users\cjang\Desktop\impedance_data\python_notebooks\utils\tools.py:172: FutureWarning: `imag` is deprecated and will be removed in a future version. To eliminate this warning for a Series `ser`, use `np.imag(ser.to_numpy())` or `ser.to_numpy().imag`.
#   self.rr_real.append(residual_real(re=self.df[i].re.values, fit_re=self.circuit_fit[i].real, fit_im=-self.circuit_fit[i].imag))
# ...
