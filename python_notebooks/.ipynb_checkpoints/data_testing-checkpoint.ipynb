# %% [markdown]
# # Custom Impedance Fitting Function
# Borrowing from the PyEIS Library, this page demonstrates how to use the Electrochemical Spectroscopy fitting function

# %%
#PyEIS Library#
#from utils.tools import *
from PyEIS import *

# %%
#Locate the data, prepare for import of the MPT file

#EXAMPLE
path=r"C:\Users\cjang\Desktop\impedance_data\data\\"
data = ['DE_40_1_30.mpt']

# %%
#WE WILL TREAT ONE ITEM AS AN EIS OBJECT, THE OTHER AS A DATAFRAME
def importer(path, data, mask_front, mask_back):
    mpt_data = EIS_exp(path, data, mask = [mask_front, mask_back])
    df = mpt_data.df_raw
    mpt_data.EIS_plot()
    return [mpt_data, df]


mpt_data = importer(path, data, 10**6, 10**1.5)[0]

df = importer(path, data, 10**6, 10**1.5)[1]

# %%
#THIS IS THE LINEAR KRAMER KRONIG ANALYSIS SECTION
#NOT NESSESCARY AT THE MOMENT, BUT THIS WILL HELP ADJUST THE MASK
#WILL HELP PREVENT WITH LONG FITTING PROCESSES

mpt_data.Lin_KK(plot='w_data')
# Out:
# cycle || No. RC-elements ||   u
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-8d471ab927f2> in <module>
#       3 #WILL HELP PREVENT WITH LONG FITTING PROCESSES
#       4
# ----> 5 mpt_data.Lin_KK(plot='w_data')
#
# c:\Users\cjang\Desktop\impedance_data\python_notebooks\PyEIS\PyEIS.py in Lin_KK(self, num_RC, legend, plot, bode, nyq_xlim, nyq_ylim, weight_func, savefig)
#    2417                     self.Rparam[i] = KK_Rnam_val(re=self.df[i].re, re_start=self.df[i].re.idxmin(), num_RC=int(self.number_RC[i]))[0] #Creates intial guesses for R's
#    2418                     self.t_const[i] = KK_timeconst(w=self.df[i].w, num_RC=int(self.number_RC[i])) #Creates time constants values for self.number_RC -(RC)- circuits
# -> 2419                     self.Lin_KK_Fit[i] = minimize(KK_errorfunc, self.Rparam[i], method='leastsq', args=(self.df[i].w.values, self.df[i].re.values, self.df[i].im.values, self.number_RC[i], weight_func, self.t_const[i]) ) #maxfev=99
#    2420                     self.R_names[i] = KK_Rnam_val(re=self.df[i].re, re_start=self.df[i].re.idxmin(), num_RC=int(self.number_RC[i]))[1] #creates R names
#    2421                     self.KK_R0 = np.delete(np.array(self.KK_R0), np.s_[0:len(self.KK_R0)])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2391                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2392                        calc_covar=calc_covar, **fit_kws)
# -> 2393     return fitter.minimize(method=method)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2174                         val.lower().startswith(user_method)):
#    2175                     kwargs['method'] = val
# -> 2176         return function(**kwargs)
#    2177
#    2178
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1566
#    1567         try:
# -> 1568             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1569         except AbortFitException:
#    1570             pass
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     385
#     386     if n > m:
# --> 387         raise TypeError('Improper input: N=%s must not exceed M=%s' % (n, m))
#     388
#     389     if epsfcn is None:
#
# TypeError: Improper input: N=41 must not exceed M=40

# %%
#USES THE EIS FITTING FUNCTION TO PREDICT THE FREQUENCIES OF THE MPT FILE

#INITIAL ARBITRARY GUESSES
#WILL CREATE A MANUAL FUNCTION THAT CAN ADJUST THE INITIAL GUESSES BUT FOR RIGHT NOW, RUN WITH THESE
Rs_guess = 10

R_guess = 2959
n_guess = 0.8
fs_guess = 23023

R2_guess = 258738
n2_guess = 0.8
fs2_guess = 0.2



#USE THE PARAMETERS DATA STRUCTURE TO WRAP THE INITIAL VALUES
params = Parameters()
params.add('Rs', value=R_guess, min=Rs_guess*.01, max=Rs_guess*100)

params.add('R', value=R_guess, min=R_guess*.1, max=R_guess*10)
params.add('n', value=n_guess, min=.65, max=1.2)
params.add('fs', value=fs_guess, min=10**0.5, max=10**6)
#params.add('Q', value=fs_guess, min=10**0.5, max=10**6)

params.add('R2', value=R2_guess, min=R2_guess*.1, max=R2_guess*10)
params.add('n2', value=n2_guess, min=.65, max=1.2)
params.add('fs2', value=fs2_guess, min=10**-2, max=10**1)
#params.add('Q2', value=fs2_guess, min=10**-2, max=10**2)



#FIT THE PARAMETERS ALONG THE R - RQ - RQ CIRCUIT
#LATER WILL PROVIDE OPTIONS TO BENEFITS AND DETRACTIONS OF THE WEIGHT FUNCTION AFTER FURTHER RESEARCH
#print(mpt_data.df[0].keys())
mpt_data.mpt_fit(params=params, circuit='R-RQ-RQ', weight_func='modulus')
#THIS WILL OUTPUT A SET OF COEFFICIENTS PREDICTED FROM THE FIT

# %%
#PLOTS THE PREDICTIONS
mpt_data.mpt_plot(fitting = 'on')

# %%
#FIRST BATCH OF FITTED COEFFICIENTS, PLUG BACK INTO THE GUESS FUNCTION TO GET EVEN BETTER BATCH

print(mpt_data.fit_Rs)
print(mpt_data.fit_R)
print(mpt_data.fit_n)
print(mpt_data.fit_fs)
print(mpt_data.fit_R2)
print(mpt_data.fit_n2)
print(mpt_data.fit_fs2)
# Out:
# [0.33939310882604573]
# [838.2107762482949]
# [0.9063901752049042]
# [26387.067720550822]
# [655109.923180833]
# [0.6502061292088703]
# [1.369205867619109]

# %%
guess_package = [mpt_data.fit_Rs[0], mpt_data.fit_R[0], mpt_data.fit_n[0], mpt_data.fit_fs[0], mpt_data.fit_R2[0], mpt_data.fit_n2[0], mpt_data.fit_fs2[0]]
guess_package
# Out:
# [0.33939310882604573,
#  838.2107762482949,
#  0.9063901752049042,
#  26387.067720550822,
#  655109.923180833,
#  0.6502061292088703,
#  1.369205867619109]

# %%
#input: A GUESS PACKAGE OF INITIAL VARIABLE COEFFICIENTS TO CALCULATE THRU CIRCUIT EQ
#output: A NEW GUESS PACKAGE THAT RAN THROUGH ONE ITERATION OF THE GUESS FUNCTION, Possibly use output for another iteration
def guess(guess_package):
    
    #SINGLE ITERATION OF THE GUESS PROCESS
    #USE THIS FUNCTION TO GET CLOSER TO THE IDEAL COEFFICIENTS FOR Rs, R, n, fs, R2, n2, fs2
    #REPEAT THIS FUNCTION UNTIL THE THRESHOLD IS ACHEIVED
    
    params = Parameters()
    
    #adding to the parameters package to send to the fitting function
    params.add('Rs', value=guess_package[0], min=guess_package[0]*.01, max=guess_package[0]*100)
    params.add('R', value=guess_package[1], min=guess_package[1]*.1, max=guess_package[1]*10)
    params.add('n', value=guess_package[2], min=.65, max=1.2)
    params.add('fs', value=guess_package[3], min=10**0.5, max=10**6)
    params.add('R2', value=guess_package[4], min=guess_package[4]*.1, max=guess_package[4]*10)
    params.add('n2', value=guess_package[5], min=.65, max=1.2)
    params.add('fs2', value=guess_package[6], min=10**-2, max=10**1)
    
    #Call to the fitting function given by PyEIS
    mpt_data.mpt_fit(params=params, circuit='R-RQ-RQ', weight_func='modulus')
    
    #maybe take a look at the plots,may help for accuracy, don't really need it...
    #mpt_data.EIS_plot(fitting = 'on')
    
    
    #print out the values
    print(mpt_data.fit_Rs)
    print()
    print(mpt_data.fit_R)
    print(mpt_data.fit_n)
    print(mpt_data.fit_fs)
    print()
    print(mpt_data.fit_R2)
    print(mpt_data.fit_n2)
    print(mpt_data.fit_fs2)
    
    #export the new guess package
    guess_package =  ([mpt_data.fit_Rs[0],mpt_data.fit_R[0],mpt_data.fit_n[0],mpt_data.fit_fs[0],mpt_data.fit_R2[0],mpt_data.fit_n2[0],mpt_data.fit_fs2[0]])
    return guess_package

# %%
new_guess_package = [i for i in guess(guess_package)]
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 79328
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.56105104
#     reduced chi-square = 0.04460146
#     Akaike info crit   = -124.277032
#     Bayesian info crit = -112.113344
# [[Variables]]
#     Rs:   0.00339393 +/- 5.5025e-04 (16.21%) (init = 0.3393931)
#     R:    1142.81720 +/- 38667.6231 (3383.54%) (init = 838.2108)
#     n:    0.74462033 +/- 2.15647996 (289.61%) (init = 0.9063902)
#     fs:   39405.5474 +/- 707981.143 (1796.65%) (init = 26387.07)
#     R2:   1251863.30 +/- 1.7713e+09 (141494.76%) (init = 655109.9)
#     n2:   0.79575516 +/- 8.10019864 (1017.93%) (init = 0.6502061)
#     fs2:  3.36944940 +/- 5895.79054 (174977.86%) (init = 1.369206)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -1.000
#     C(R2, fs2) = -0.999
#     C(R, n)    = -0.998
#     C(R, n2)   =  0.998
#     C(n, fs)   =  0.995
#     C(fs, n2)  = -0.995
#     C(fs, R2)  = -0.546
#     C(R, R2)   =  0.522
#     C(fs, fs2) =  0.516
#     C(R, fs2)  = -0.492
#     C(R2, n2)  =  0.462
#     C(n, R2)   = -0.461
#     C(Rs, fs2) = -0.431
#     C(n2, fs2) = -0.430
#     C(n, fs2)  =  0.430
#     C(Rs, R2)  =  0.410
#     C(Rs, n2)  = -0.352
#     C(Rs, n)   =  0.346
#     C(Rs, R)   = -0.299
#     C(Rs, fs)  =  0.272
# None
# [0.003393931088264225]
#
# [1142.8172042843833]
# [0.7446203259535705]
# [39405.547426281846]
#
# [1251863.3025146888]
# [0.7957551618689727]
# [3.369449399709677]

# %%
new_guess_package
# Out:
# [0.003393931088264225,
#  1142.8172042843833,
#  0.7446203259535705,
#  39405.547426281846,
#  1251863.3025146888,
#  0.7957551618689727,
#  3.369449399709677]

# %%
guess_package
# Out:
# [0.33939310882604573,
#  838.2107762482949,
#  0.9063901752049042,
#  26387.067720550822,
#  655109.923180833,
#  0.6502061292088703,
#  1.369205867619109]

# %%
#THIS VERIFIES WHETHER OR NOT WE'VE ACHEIVED A SATISFACTORY COEFFICIENT PACKAGE
#IF THIS DOESN'T RETURN TRUE, WE RUN THE GUESSER UNTIL IT DOES
def thresh_verif(before, after):
    try:
        total = 0
        for i in range(len(before)):
            total += (before[i] - after[i])
        print(total)    
        return abs(total) <= 5e-10
    except IndexError as e:
        #IF LISTS AREN'T THE SAME LENGTH
        print("Lists are not the same length")
        return

# %%
thresh_verif(guess_package, new_guess_package)
# Out:
# -610078.1134911607
# False

# %%
new_new_guess_package = guess(new_guess_package)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 36
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.56066518
#     reduced chi-square = 0.04459043
#     Akaike info crit   = -124.287415
#     Bayesian info crit = -112.123727
# [[Variables]]
#     Rs:   3.3984e-05 +/- 49.9282892 (146918221.57%) (init = 0.003393931)
#     R:    1142.81751 +/- 39408.2334 (3448.34%) (init = 1142.817)
#     n:    0.74461995 +/- 2.19945812 (295.38%) (init = 0.7446203)
#     fs:   39405.5714 +/- 721062.021 (1829.85%) (init = 39405.55)
#     R2:   1251863.74 +/- 1.6808e+09 (134267.17%) (init = 1251863)
#     n2:   0.79575514 +/- 8.26226627 (1038.29%) (init = 0.7957552)
#     fs2:  3.36945094 +/- 5579.97737 (165604.94%) (init = 3.369449)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -1.000
#     C(R2, fs2) = -0.999
#     C(R, n2)   =  0.998
#     C(R, n)    = -0.998
#     C(n, fs)   =  0.996
#     C(fs, n2)  = -0.996
#     C(fs, R2)  = -0.567
#     C(R, R2)   =  0.546
#     C(fs, fs2) =  0.536
#     C(R, fs2)  = -0.514
#     C(R2, n2)  =  0.493
#     C(n, R2)   = -0.492
#     C(n2, fs2) = -0.460
#     C(n, fs2)  =  0.459
#     C(Rs, n2)  = -0.395
#     C(Rs, n)   =  0.389
#     C(Rs, R)   = -0.350
#     C(Rs, fs2) = -0.343
#     C(Rs, fs)  =  0.327
#     C(Rs, R2)  =  0.319
# None
# [3.398372825804981e-05]
#
# [1142.81751463557]
# [0.7446199494010849]
# [39405.57142155306]
#
# [1251863.7439472803]
# [0.7957551379492502]
# [3.369450938897329]

# %%
for i in range(len(new_guess_package)):
    print(new_new_guess_package[i] - new_guess_package[i])
# Out:
# -0.0033599473600061753
# 0.00031035118672662065
# -3.7655248563694954e-07
# 0.023995271214516833
# 0.4414325915277004
# -2.3919722424992074e-08
# 1.539187651999896e-06

# %%
thresh_verif(new_guess_package, new_new_guess_package)
# Out:
# -0.46237940528438165
# False

# %%
new_new_new_guess_package = guess(new_new_guess_package)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 24
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.56066518
#     reduced chi-square = 0.04459043
#     Akaike info crit   = -124.287415
#     Bayesian info crit = -112.123727
# [[Variables]]
#     Rs:   3.3984e-05 +/- 6.33282264 (18634867.23%) (init = 3.398373e-05)
#     R:    1142.81751 +/- 38590.2557 (3376.76%) (init = 1142.818)
#     n:    0.74461995 +/- 2.15293252 (289.13%) (init = 0.7446199)
#     fs:   39405.5714 +/- 706596.611 (1793.14%) (init = 39405.57)
#     R2:   1251863.74 +/- 1.7489e+09 (139707.67%) (init = 1251864)
#     n2:   0.79575514 +/- 8.08586133 (1016.12%) (init = 0.7957551)
#     fs2:  3.36945094 +/- 5820.27152 (172736.50%) (init = 3.369451)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -1.000
#     C(R2, fs2) = -0.999
#     C(R, n)    = -0.998
#     C(R, n2)   =  0.998
#     C(n, fs)   =  0.995
#     C(fs, n2)  = -0.995
#     C(fs, R2)  = -0.545
#     C(R, R2)   =  0.522
#     C(fs, fs2) =  0.515
#     C(R, fs2)  = -0.491
#     C(R2, n2)  =  0.462
#     C(n, R2)   = -0.462
#     C(Rs, fs2) =  0.437
#     C(n2, fs2) = -0.430
#     C(n, fs2)  =  0.430
#     C(Rs, R2)  = -0.415
#     C(Rs, n2)  =  0.346
#     C(Rs, n)   = -0.340
#     C(Rs, R)   =  0.294
#     C(Rs, fs)  = -0.267
# None
# [3.398372825804984e-05]
#
# [1142.8175146355702]
# [0.7446199494010849]
# [39405.57142155306]
#
# [1251863.74394728]
# [0.7957551379492502]
# [3.369450938897329]

# %%
thresh_verif(new_new_guess_package, new_new_new_guess_package)
# Out:
# 2.3260326994454508e-10
# True

# %%
#ITERATIVE GUESSER
def guesser(Rs_guess,R_guess,n_guess,fs_guess,R2_guess,n2_guess,fs2_guess):
    guess_package = [Rs_guess, R_guess, n_guess, fs_guess, R2_guess, n2_guess, fs2_guess]
    new_guess = guess(guess_package)
    while not thresh_verif(guess_package, new_guess):
        guess_package = new_guess
        new_guess = guess(new_guess)
        print(new_guess)
    return new_guess

# %%
#CUMULATION OF THE FUNCTIONS FROM ABOVE

#GUESSES BROUGHT FROM INIT VALUES
Rs_guess = 40

R_guess = 2959
n_guess = 0.8
fs_guess = 23023

R2_guess = 258738
n2_guess = 0.8
fs2_guess = 0.2


#COMPLETE FUNCTION
guesser(Rs_guess,R_guess,n_guess,fs_guess,R2_guess,n2_guess,fs2_guess)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 2648
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.60694701
#     reduced chi-square = 0.04591277
#     Akaike info crit   = -123.060007
#     Bayesian info crit = -110.896320
# [[Variables]]
#     Rs:   0.40000000 +/- 5.39445220 (1348.61%) (init = 40)
#     R:    1118.03302 +/- 39236.7213 (3509.44%) (init = 2959)
#     n:    0.74534219 +/- 2.26339245 (303.67%) (init = 0.8)
#     fs:   40780.6955 +/- 742241.786 (1820.08%) (init = 23023)
#     R2:   1568255.87 +/- 2.3271e+09 (148386.81%) (init = 258738)
#     n2:   0.80021193 +/- 8.78702777 (1098.09%) (init = 0.8)
#     fs2:  2.71466066 +/- 5035.61831 (185497.16%) (init = 0.2)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -0.999
#     C(R2, fs2) = -0.999
#     C(R, n)    = -0.998
#     C(R, n2)   =  0.998
#     C(n, fs)   =  0.996
#     C(fs, n2)  = -0.996
#     C(Rs, R2)  =  0.681
#     C(Rs, fs2) = -0.680
#     C(fs, R2)  = -0.123
#     C(Rs, fs)  = -0.103
# None
# [0.4000000000415182]
#
# [1118.0330155471504]
# [0.7453421874704438]
# [40780.69546005313]
#
# [1568255.868811861]
# [0.8002119282724709]
# [2.714660662203595]
# -1325397.4575022392
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 24106
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.56128330
#     reduced chi-square = 0.04460809
#     Akaike info crit   = -124.270783
#     Bayesian info crit = -112.107096
# [[Variables]]
#     Rs:   0.00400000 +/- 4.69704360 (117425.97%) (init = 0.4)
#     R:    1136.19629 +/- 40959.1029 (3604.93%) (init = 1118.033)
#     n:    0.74399704 +/- 2.30707177 (310.09%) (init = 0.7453422)
#     fs:   39900.3527 +/- 748118.202 (1874.97%) (init = 40780.7)
#     R2:   1554298.85 +/- 2.2907e+09 (147378.28%) (init = 1568256)
#     n2:   0.79918649 +/- 9.04610217 (1131.91%) (init = 0.8002119)
#     fs2:  2.68663184 +/- 4948.15255 (184176.80%) (init = 2.714661)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -1.000
#     C(R2, fs2) = -0.999
#     C(R, n)    = -0.998
#     C(R, n2)   =  0.998
#     C(n, fs)   =  0.996
#     C(fs, n2)  = -0.996
#     C(Rs, R2)  =  0.687
#     C(Rs, fs2) = -0.680
#     C(Rs, fs)  = -0.270
#     C(Rs, R)   =  0.243
#     C(Rs, n)   = -0.201
#     C(Rs, n2)  =  0.196
#     C(fs, R2)  = -0.167
#     C(R, R2)   =  0.139
#     C(fs, fs2) =  0.124
# None
# [0.004000004123955078]
#
# [1136.1962851773374]
# [0.7439970393264895]
# [39900.35266570234]
#
# [1554298.850749145]
# [0.79918648979289]
# [2.6866318430036538]
# [0.004000004123955078, 1136.1962851773374, 0.7439970393264895, 39900.35266570234, 1554298.850749145, 0.79918648979289, 2.6866318430036538]
# 14819.62398683823
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 36
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.56083945
#     reduced chi-square = 0.04459541
#     Akaike info crit   = -124.282725
#     Bayesian info crit = -112.119038
# [[Variables]]
#     Rs:   4.0179e-05 +/- 95.1276142 (236757444.29%) (init = 0.004000004)
#     R:    1136.19726 +/- 40574.7270 (3571.10%) (init = 1136.196)
#     n:    0.74399623 +/- 2.28879044 (307.63%) (init = 0.743997)
#     fs:   39900.3891 +/- 740404.999 (1855.63%) (init = 39900.35)
#     R2:   1554298.96 +/- 2.3106e+09 (148658.58%) (init = 1554299)
#     n2:   0.79918643 +/- 8.97666349 (1123.23%) (init = 0.7991865)
#     fs2:  2.68663214 +/- 4996.85939 (185989.71%) (init = 2.686632)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -0.999
#     C(R2, fs2) = -0.999
#     C(R, n)    = -0.998
#     C(R, n2)   =  0.998
#     C(n, fs)   =  0.996
#     C(fs, n2)  = -0.996
#     C(Rs, R2)  =  0.692
#     C(Rs, fs2) = -0.687
#     C(Rs, fs)  = -0.234
#     C(Rs, R)   =  0.206
#     C(Rs, n)   = -0.163
#     C(Rs, n2)  =  0.157
#     C(fs, R2)  = -0.144
#     C(R, R2)   =  0.115
#     C(fs, fs2) =  0.101
# None
# [4.0179355051844204e-05]
#
# [1136.1972562671529]
# [0.7439962313806638]
# [39900.38907341479]
#
# [1554298.959866816]
# [0.7991864257306229]
# [2.6866321442206864]
# [4.0179355051844204e-05, 1136.1972562671529, 0.7439962313806638, 39900.38907341479, 1554298.959866816, 0.7991864257306229, 2.6866321442206864]
# -0.1425360776256438
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 24
#     # data points      = 42
#     # variables        = 7
#     chi-square         = 1.56083945
#     reduced chi-square = 0.04459541
#     Akaike info crit   = -124.282725
#     Bayesian info crit = -112.119038
# [[Variables]]
#     Rs:   4.0179e-05 +/- 6.05942206 (15080934.11%) (init = 4.017936e-05)
#     R:    1136.19726 +/- 40980.2057 (3606.79%) (init = 1136.197)
#     n:    0.74399623 +/- 2.30762343 (310.17%) (init = 0.7439962)
#     fs:   39900.3891 +/- 748626.893 (1876.24%) (init = 39900.39)
#     R2:   1554298.96 +/- 2.3034e+09 (148194.37%) (init = 1554299)
#     n2:   0.79918643 +/- 9.04812788 (1132.17%) (init = 0.7991864)
#     fs2:  2.68663214 +/- 4974.81921 (185169.35%) (init = 2.686632)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(n, n2)   = -1.000
#     C(R, fs)   = -1.000
#     C(R2, fs2) = -0.999
#     C(R, n)    = -0.998
#     C(R, n2)   =  0.998
#     C(n, fs)   =  0.996
#     C(fs, n2)  = -0.996
#     C(Rs, R2)  = -0.688
#     C(Rs, fs2) =  0.682
#     C(Rs, fs)  =  0.274
#     C(Rs, R)   = -0.248
#     C(Rs, n)   =  0.206
#     C(Rs, n2)  = -0.200
#     C(fs, R2)  = -0.171
#     C(R, R2)   =  0.143
#     C(fs, fs2) =  0.128
#     C(R, fs2)  = -0.100
# None
# [4.017935505184424e-05]
#
# [1136.197256267153]
# [0.7439962313806638]
# [39900.38907341479]
#
# [1554298.9598668164]
# [0.7991864257306229]
# [2.6866321442206864]
# [4.017935505184424e-05, 1136.197256267153, 0.7439962313806638, 39900.38907341479, 1554298.9598668164, 0.7991864257306229, 2.6866321442206864]
# -4.658886610170638e-10
# [4.017935505184424e-05,
#  1136.197256267153,
#  0.7439962313806638,
#  39900.38907341479,
#  1554298.9598668164,
#  0.7991864257306229,
#  2.6866321442206864]

# %%
mpt_data.mpt_plot(fitting = 'on')
