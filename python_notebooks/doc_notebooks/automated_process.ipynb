# %% [markdown]
# # Automated Process(DEPRECATED)
#
# In conclusion, all the steps used above can be combined and slotted into a single function which can be used once to return a full set of optimal coefficients

# %% [markdown]
# # UPDATE 3/17/20: THIS IS NOW DEPRECATED, CAN'T FULLY AUTOMATE

# %%
#Locate the data, prepare for import of the MPT file
#Import necessary packaging
from utils.script_utils.tools import *
path=r"C:\Users\cjang\Desktop\Kyler_Speed_Circuit\data\\"
data = ['DE_40_1_30.mpt']
ex_mpt = mpt_data(path,data)

# %%
#THIS IS A FULLY AUTOMATED FITTING PROCESS
def check_list(path):
    path_files = [f for f in listdir(path) if isfile(join(path, f)) if f[-3:] == 'mpt']
    for i in path_files:
        print(i)
    #print(path_files) 

def full_graphing(path, lst = None):
    bad_mpts = []
    if not lst:
        path_files = [f for f in listdir(path) if isfile(join(path, f)) if f[-3:] == 'mpt']
        for i in path_files:
            try:
                print(i, ' was a permissible file')
                ex_mpt = mpt_data(path,[i])
                masked_mpt = mpt_data(path,[i], mask = ex_mpt.masker())
                masked_mpt.set_new_gph_dims(30,30)
                masked_mpt.mpt_plot()
                plt.show()
            except ValueError:
                bad_mpts.append(i)
                print(i, ' was a bad file, could not find a mask')
        if bad_mpts:
            print(bad_mpts, " are a list of bad mpts. You may want to take a closer look at them")
    if type(lst) == list:
        for i in lst:
            try:
                print(i, ' was a permissible file')
                ex_mpt = mpt_data(path,[i])
                masked_mpt = mpt_data(path,[i], mask = ex_mpt.masker())
                masked_mpt.set_new_gph_dims(30,30)
                masked_mpt.mpt_plot()
            except ValueError:
                bad_mpts.append(i)
                print(i, ' was a bad file, could not find a mask')
            if bad_mpts:
                print(bad_mpts, " are a list of bad mpts. You may want to take a closer look at them")
                

def the_ringer(path, single_file):
        print('WHOLE THING')
        ex_mpt = mpt_data(path,[single_file])
        ex_mpt.mpt_plot()
        
        print('FAST MASK')
        print(ex_mpt.fast_mask())
        fast_masked_mpt = mpt_data(path, [single_file], mask = ex_mpt.fast_mask())
        fast_masked_mpt.mpt_plot()
        
        print('MASKER0')
        print(ex_mpt.masker0())
        masker0_mpt = mpt_data(path, [single_file], mask = ex_mpt.masker0())
        masker0_mpt.mpt_plot()
        
        print('MASKER')
        print(ex_mpt.masker())
        masker_mpt = mpt_data(path, [single_file], mask = ex_mpt.masker())
        masker_mpt.mpt_plot()

def auto_fit(path, lst = None, csv_container = None):

    bad_mpts = []
    path_files = [f for f in listdir(path) if isfile(join(path, f)) if f[-3:] == 'mpt']
    if not lst:
        for i in path_files:
            try:
                #print(i, ' was a permissible file')
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                masked_mpt = mpt_data(path,[i], mask = ex_mpt.masker())
                masked_mpt.guesser(csv_container = csv_container)
            
            except ValueError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                bad_mpts.append(i)
                ex_mpt.mpt_plot()
                print(i, ' was a bad file, could not find a mask')
            except TypeError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                ex_mpt.guesser(csv_container = csv_container)
                print(i, ' was fittable, but could not obtain a mask')
    for i in lst:
            try:
                #print(i, ' was a permissible file')
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                masked_mpt = mpt_data(path,[i], mask = ex_mpt.masker())
                masked_mpt.guesser(csv_container = csv_container)
            except ValueError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                bad_mpts.append(i)
                ex_mpt.mpt_plot()
                print(i, ' was a bad file, could not find a mask')
            except TypeError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                ex_mpt.guesser(csv_container = csv_container)
                print(i, ' was fittable, but could not obtain a mask')

# %%
check_list(path)
# Out:
# DE_40_10_60.mpt
# DE_40_11_60.mpt
# DE_40_12_60.mpt
# DE_40_13_60.mpt
# DE_40_14_60.mpt
# DE_40_15_60.mpt
# DE_40_1_30.mpt
# DE_40_2_60.mpt
# DE_40_3_60.mpt
# DE_40_4_60.mpt
# DE_40_5_60.mpt
# DE_40_6_60.mpt
# DE_40_7_60.mpt
# DE_40_8_60.mpt
# DE_40_9_60.mpt
# DE_49_1_30.mpt
# DE_49_2_30.mpt
# DE_49_3_30.mpt
# DE_49_4_30.mpt
# DE_49_5_30.mpt
# DE_49_6_30.mpt
# DE_49_7_30.mpt
# DE_49_8_30.mpt
# DE_49_9_30.mpt
# DE_57_6_60.mpt

# %%
full_graphing(path)
# Out:
# No handles with labels found to put in legend.
# DE_40_10_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_11_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_12_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_13_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_14_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_15_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_1_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_2_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_3_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_4_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_5_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_6_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_7_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_8_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_40_9_60.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_1_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_2_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_3_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_4_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_5_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_6_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_7_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_8_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_49_9_30.mpt  was a permissible file
# No handles with labels found to put in legend.
# DE_57_6_60.mpt  was a permissible file

# %%
the_ringer(path, 'DE_40_1_30.mpt')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# WHOLE THING
# FAST MASK
# [1000018.6, 630956.81]
# MASKER0
# [1000018.6, 177831.8]
# MASKER
# [1000018.6, 251187.64]

# %%
#for the purpose of time, we'll make a mini list and run the full_auto fitter on it
list_to_fit =['DE_49_7_30.mpt','DE_49_8_30.mpt','DE_49_9_30.mpt']

# %%
def auto_fit(path, entry, csv_container = None):
    bad_mpts = []

    fitteds = []
    if type(entry) == list:
        for i in entry:
            try:
                #print(i, ' was a permissible file')
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                masked_mpt = mpt_data(path,[i], mask = ex_mpt.masker())
                fitteds.append(masked_mpt.guesser(csv_container = csv_container))
            except ValueError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                bad_mpts.append(i)
                ex_mpt.mpt_plot()
                print(i, ' was a bad file, could not find a mask')
            except TypeError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                ex_mpt.guesser(csv_container = csv_container)
                print(i, ' was fittable, but could not obtain a mask')
    
    if type(entry) == str:
        path_files = [f for f in listdir(path) if isfile(join(path, f)) if f[-3:] == 'mpt']
        for i in path_files:
            try:
                #print(i, ' was a permissible file')
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                masked_mpt = mpt_data(path,[i], mask = ex_mpt.masker())
                fitteds.append(masked_mpt.guesser(csv_container = csv_container))
            except ValueError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                bad_mpts.append(i)
                ex_mpt.mpt_plot()
                print(i, ' was a bad file, could not find a mask')
            except TypeError:
                ex_mpt = mpt_data(path,[i])
                out_name = 'fitted_' + ex_mpt.data[0][:-4]
                ex_mpt.guesser(csv_container = csv_container)
                print(i, ' was fittable, but could not obtain a mask')
    
    to_export = pd.concat(fitteds)
    return to_export

# %%
auto_fit(path, list_to_fit)
# Out:
# _49_9_30.mpt  ERROR:  44936593.93184963
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935642.00146198
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 20
#     # data points      = 166
#     # variables        = 9
#     chi-square         = 14085.6203
#     reduced chi-square = 89.7173266
#     Akaike info crit   = 755.193040
#     Bayesian info crit = 783.200930
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at initial value
#     R:    at initial value
#     n:    at initial value
#     fs:   at initial value
#     R2:   at initial value
#     n2:   at initial value
#     fs2:  at initial value
#     n3:   at initial value
#     fs3:  at initial value
#     fs3:  at boundary
# [[Variables]]
#     Rs:   0.61986394 (init = 0.6198639)
#     R:    159061.868 (init = 159061.9)
#     n:    0.96328999 (init = 0.96329)
#     fs:   594.496410 (init = 594.4964)
#     R2:   687477.289 (init = 687477.3)
#     n2:   0.66362038 (init = 0.6636204)
#     fs2:  2.33194922 (init = 2.331949)
#     n3:   0.95729423 (init = 0.9572942)
#     fs3:  10.0000000 (init = 10)
# None
# ITERATION NO. :  97
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935642.00146265
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935642.00146265
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935642.00146265
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935641.99732669
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935530.06171418
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935640.01671519
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934619.57646181
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935613.54683584
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935645.54472529
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935635.36443271
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935642.00146091
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935642.00146265
# MPT FILE :  DE_49_9_30.mpt  ERROR:  355309909.75682193
# MPT FILE :  DE_49_9_30.mpt  ERROR:  52984360.32936416
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44694885.791532695
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44736400.735657334
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44854295.928122796
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44910972.52288529
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44929701.37321219
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935930.437469825
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935930.433334425
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935818.49485642
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935928.45271483
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934908.00485982
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935901.98183156
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935933.98084557
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935923.80012363
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935930.436952956
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935930.437469825
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981206
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.75884651
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937054.8059398
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937164.77806328
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44936144.24210516
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937138.30418648
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937170.30684381
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937160.12480858
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.76331794
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981206
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44939107.45185143
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981206
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 166
#     # variables        = 9
#     chi-square         = 14085.6132
#     reduced chi-square = 89.7172813
#     Akaike info crit   = 755.192956
#     Bayesian info crit = 783.200847
# ##  Warning: uncertainties could not be estimated:
#     R:    at initial value
#     n:    at initial value
#     fs:   at initial value
#     R2:   at initial value
#     n2:   at initial value
#     fs2:  at initial value
#     fs3:  at initial value
#     fs3:  at boundary
# [[Variables]]
#     Rs:   0.61923029 (init = 0.6198639)
#     R:    159061.854 (init = 159061.9)
#     n:    0.96329004 (init = 0.96329)
#     fs:   594.496190 (init = 594.4964)
#     R2:   687479.752 (init = 687477.3)
#     n2:   0.66362022 (init = 0.6636204)
#     fs2:  2.33192801 (init = 2.331949)
#     n3:   0.99673338 (init = 0.9572942)
#     fs3:  10.0000000 (init = 10)
# None
# ITERATION NO. :  98
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.758848704
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937054.80594769
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937164.778062716
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44936144.24210484
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937138.304097444
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937170.30684337
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937160.12480824
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762979984
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937166.762981
# MPT FILE :  DE_49_9_30.mpt  ERROR:  80896334931.38815
# MPT FILE :  DE_49_9_30.mpt  ERROR:  91371460.88556224
# MPT FILE :  DE_49_9_30.mpt  ERROR:  45631028.656341866
# MPT FILE :  DE_49_9_30.mpt  ERROR:  45106068.114950165
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44892300.58343735
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44894526.64717563
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920415.32429847
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920415.320158675
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920303.61111188
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920413.343579024
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44919395.59577042
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920386.879442945
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920418.86195752
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920408.689344846
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920415.32752779
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920415.32429847
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921536.989507444
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921536.98536937
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921425.266202964
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921535.008663796
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44920517.199218325
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921508.54221541
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921540.527498856
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921530.35382426
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921536.99006152
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44921536.989507444
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924919.73373182
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924919.72959584
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924807.97182116
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924917.75241424
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923899.6862813
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924891.27855076
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924923.27298879
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924913.09600079
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924919.73563101
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44924919.73373182
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.00580986
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.00580986
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 166
#     # variables        = 9
#     chi-square         = 14085.5824
#     reduced chi-square = 89.7170855
#     Akaike info crit   = 755.192594
#     Bayesian info crit = 783.200484
# ##  Warning: uncertainties could not be estimated:
#     R:    at initial value
#     n:    at initial value
#     fs:   at initial value
#     n2:   at initial value
#     fs3:  at initial value
#     fs3:  at boundary
# [[Variables]]
#     Rs:   0.62175627 (init = 0.6192303)
#     R:    159062.895 (init = 159061.9)
#     n:    0.96329098 (init = 0.96329)
#     fs:   594.498113 (init = 594.4962)
#     R2:   687498.972 (init = 687479.8)
#     n2:   0.66361458 (init = 0.6636202)
#     fs2:  2.33166206 (init = 2.331928)
#     n3:   0.98796348 (init = 0.9967334)
#     fs3:  10.0000000 (init = 10)
# None
# ITERATION NO. :  99
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.005810246
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.005810246
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.005810246
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.00166607
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927376.211760186
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927486.02410917
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44926467.75819191
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927459.54345167
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927491.54610766
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927481.36641663
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.00580869
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44927488.005810246
# MPT FILE :  DE_49_9_30.mpt  ERROR:  70969324503.15758
# MPT FILE :  DE_49_9_30.mpt  ERROR:  101576021.34718663
# MPT FILE :  DE_49_9_30.mpt  ERROR:  48100039.96812414
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44795780.82672559
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44823026.97346039
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44893631.65964148
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923479.907672584
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923479.90352751
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923368.1725267
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923477.92698785
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44922460.320872605
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923451.44891288
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923483.44645049
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923473.2690603
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923479.90921402
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44923479.907672584
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930311.51878241
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930311.51464073
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930199.70938625
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930309.537260786
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44929291.527657345
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930283.04225753
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930315.060138896
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930304.875655815
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930311.51784815
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930311.51878241
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.349252015
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.345111705
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44932928.50925586
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933038.36737217
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44932020.16777587
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933011.86606157
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933043.89163621
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933033.70441689
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34996557
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.349252015
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44936245.40483371
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.349252015
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 166
#     # variables        = 9
#     chi-square         = 14085.5633
#     reduced chi-square = 89.7169637
#     Akaike info crit   = 755.192369
#     Bayesian info crit = 783.200259
# ##  Warning: uncertainties could not be estimated:
#     R:    at initial value
#     n:    at initial value
#     fs:   at initial value
#     n2:   at initial value
#     fs3:  at initial value
#     fs3:  at boundary
# [[Variables]]
#     Rs:   0.62007026 (init = 0.6217563)
#     R:    159063.039 (init = 159062.9)
#     n:    0.96329132 (init = 0.963291)
#     fs:   594.497696 (init = 594.4981)
#     R2:   687506.030 (init = 687499)
#     n2:   0.66361329 (init = 0.6636146)
#     fs2:  2.33156190 (init = 2.331662)
#     n3:   0.99736632 (init = 0.9879635)
#     fs3:  10.0000000 (init = 10)
# None
# ITERATION NO. :  100
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34925152
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34925152
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34925152
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34511787
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44932928.50916739
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933038.367371626
# MPT FILE : DE_49_9_30.mpt  ERROR:  44932020.16777511
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933011.86580749
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933043.891635776
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933033.704416394
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34925048
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933040.34925152
# MPT FILE :  DE_49_9_30.mpt  ERROR:  15814954712.843515
# MPT FILE :  DE_49_9_30.mpt  ERROR:  61656936.6205353
# MPT FILE :  DE_49_9_30.mpt  ERROR:  46700136.231250525
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44909865.77915867
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44869893.88403486
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44910718.14057921
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931223.258688346
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931223.254552916
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931111.45137634
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931221.27731692
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44930203.57533747
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931194.7742719
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931226.800343476
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931216.613465644
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931223.25465026
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44931223.258688346
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934015.06463275
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934015.06049951
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933903.22849747
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934013.08295272
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44932995.20819403
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44933986.57344484
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934018.607276104
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934008.417643026
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934015.058792345
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934015.06463275
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499816
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.290866256
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935874.4386129
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935984.31308673
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934966.29340622
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935957.79964191
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935989.83830628
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935979.64692248
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.293415725
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499816
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44937116.13595912
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499816
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 166
#     # variables        = 9
#     chi-square         = 14085.5533
#     reduced chi-square = 89.7168999
#     Akaike info crit   = 755.192251
#     Bayesian info crit = 783.200141
# ##  Warning: uncertainties could not be estimated:
#     R:    at initial value
#     n:    at initial value
#     fs:   at initial value
#     n2:   at initial value
#     fs3:  at initial value
#     fs3:  at boundary
# [[Variables]]
#     Rs:   0.61943047 (init = 0.6200703)
#     R:    159063.176 (init = 159063)
#     n:    0.96329137 (init = 0.9632913)
#     fs:   594.497426 (init = 594.4977)
#     R2:   687513.860 (init = 687506)
#     n2:   0.66361187 (init = 0.6636133)
#     fs2:  2.33147122 (init = 2.331562)
#     n3:   0.85683765 (init = 0.9973663)
#     fs3:  10.0000000 (init = 10)
# None
# ITERATION NO. :  101
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499729
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499729
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499729
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.290867805
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935874.438528284
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935984.31308607
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44934966.29340552
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935957.79935948
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935989.838305235
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935979.64692139
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.294997334
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44935986.29499729
# MPT FILE :  DE_49_9_30.mpt  ERROR:  3839269700.84284
# MPT FILE :  DE_49_9_30.mpt  ERROR:  46689609.83160913
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867172.80127961
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867172.798121646
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867057.56081336
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867170.82157813
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44866143.8266726
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867143.7358402
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867176.4893492
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867165.33183412
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867172.799906015
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44867172.80127961
# MPT FILE :  DE_49_9_30.mpt  ERROR:  45806305.12395242
# MPT FILE :  DE_49_9_30.mpt  ERROR:  42899705.49554409
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44226273.30552869
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495215.32081631
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495215.3177328
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495103.969672605
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495213.39028304
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44494195.70669222
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495187.38961335
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495218.86208519
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495208.1541752
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495215.32122463
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44495215.32081631
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44516004.213099286
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44516004.21005992
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44515892.62983967
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44516002.28140735
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44514982.47776611
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44515976.23958735
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44516007.76209302
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44515997.034391224
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44516004.21348302
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44516004.213099286
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525873.62941973
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525873.62640104
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525761.93074635
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525871.696903095
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44524850.64696565
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525845.6405033
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525877.18191843
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525866.4461399
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525873.62789451
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44525873.62941973
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530933.23733239
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530933.234332636
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530821.46224025
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530931.30420536
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44529908.90496199
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530905.2508553
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530936.79148826
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530926.05412446
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530933.23870489
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44530933.23733239
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534448.51571208
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534448.51271704
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534336.70224738
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534446.58223753
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44533423.83437893
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534420.52288224
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534452.07108471
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534441.330694005
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534448.51788031
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44534448.51571208
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44538074.30969231
# MPT FILE :  DE_49_9_30.mpt  ERROR:  44538074.30969231
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 76
#     # data points      = 166
#     # variables        = 9
#     chi-square         = 14062.6624
#     reduced chi-square = 89.5710979
#     Akaike info crit   = 754.922259
#     Bayesian info crit = 782.930149
# ##  Warning: uncertainties could not be estimated:
#     fs3:  at initial value
#     fs3:  at boundary
# [[Variables]]
#     Rs:   0.29811473 (init = 0.6194305)
#     R:    159148.580 (init = 159063.2)
#     n:    0.96323740 (init = 0.9632914)
#     fs:   594.190448 (init = 594.4974)
#     R2:   705162.879 (init = 687513.9)
#     n2:   0.66309350 (init = 0.6636119)
#     fs2:  2.22835442 (init = 2.331471)
#     n3:   0.70827730 (init = 0.8568377)
#     fs3:  10.0000000 (init = 10)
# None
#              file       fit_R         fit_Rs     fit_n         fit_Q  \
# 0  DE_49_7_30.mpt  225.607085   75500.737678  0.852531  8.332172e-09
# 0  DE_49_8_30.mpt  194.492279   91430.612778  0.864334  6.662975e-09
# 0  DE_49_9_30.mpt    0.298115  159148.579723  0.963237  2.277255e-09
#
#           fit_R2    fit_n2        fit_Q2    fit_n3    fit_Q3
# 0   84218.910806  1.000000  1.973220e-07  0.983531  0.017039
# 0  124443.982971  0.999997  1.290185e-07  0.889474  0.025152
# 0  705162.879017  0.663094  2.464317e-07  0.708277  0.053259
